# %% [markdown]
# Rounding to the Nearest Integer
# 1. 1465s Best objective 1.418666111154e+09, best bound 1.418794252917e+09, gap 0.0090%

# %% [markdown]
# No Rounding
# 1. 2283s Best objective 1.418098825912e+09, best bound 1.418181191274e+09, gap 0.0058%
